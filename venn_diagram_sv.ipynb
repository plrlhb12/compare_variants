# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline
#mpl.rcParams.update(mpl.rcParamsDefault)
# %config InlineBackend.figure_format = 'retina'

# %%
from matplotlib_venn import venn3, venn3_circles
from matplotlib_venn import venn2, venn2_circles

# %%
color1 = "darkorange"
color2 = 'teal'
color3 = "blue"
color4 = "seagreen"

# %%
v = venn2(subsets={'10': 5304, '01': 2320, '11': 5903}, set_labels = ('short_psomagen', 'short_jax'))

# %%
v = venn2(subsets={'10': 8176, '01': 4011, '11': 1626}, set_labels = ('long', 'short_common'),
          set_colors=(color1, color2))

# %%
v = venn2(subsets={'10': 4162, '01': 9126, '11': 1088}, set_labels = ('NIST_long', 'NIST_short'),
          set_colors=(color3, color4))
